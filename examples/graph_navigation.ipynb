# %%
from labgraph import Sample, Measurement, Material, Action, Analysis, views

# %%
samples = views.SampleView().filter({})

# %%
from labgraph.utils import plot
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(20, 10))

plot.plot_multiple_samples(samples[:250], ax)
